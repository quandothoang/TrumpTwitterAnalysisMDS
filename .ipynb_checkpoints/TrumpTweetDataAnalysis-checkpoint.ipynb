# %%
import pandas as pd

url = "https://raw.githubusercontent.com/MarkHershey/CompleteTrumpTweetsArchive/refs/heads/master/data/realDonaldTrump_in_office.csv"

tweets = pd.read_csv(
    url,
    encoding="utf-8-sig",                       # removes a BOM "Byte Order Mark" at the beginning of the file (ChatGPT assist) 
    on_bad_lines="skip"                                 # skip the lines ending in weird characters and tripping up pandas
)
tweets.columns = tweets.columns.str.strip()                         # strip white-space from before column names 
#print(tweets.columns)
tweets["Date & Time"] = pd.to_datetime(tweets["Time"], errors="coerce")     # set Time column to index and rename
tweets = tweets.drop(columns=["ID", "Tweet URL", "Time"])
tweets = tweets.set_index("Date & Time")
tweets.head(50)
# Out:
#                                                             Tweet Text
# Date & Time
# 2017-01-20 06:31:00   "It all begins today! I will see you at 11:00...
# 2017-01-20 11:54:00   "We will bring back our jobs. We will bring b...
# 2017-01-20 11:55:00   "We will follow two simple rules: BUY AMERICA...
# 2017-01-20 11:58:00   "It is time to remember that...https://www.fa...
# 2017-01-20 12:13:00   "TO ALL AMERICANS https://www.facebook.com/Do...
# 2017-01-21 05:53:00   "A fantastic day and evening in Washington D....
# 2017-01-22 06:47:00   "Watched protests yesterday but was under the...
# 2017-01-23 05:38:00   "Busy week planned with a heavy focus on jobs...
# 2017-01-24 05:11:00   "Will be meeting at 9:00 with top automobile ...
# 2017-01-24 10:58:00   "A photo delivered yesterday that will be dis...
# 2017-01-24 11:49:00   "Signing orders to move forward with the cons...
# 2017-01-24 18:46:00   "Great meeting with Ford CEO Mark Fields and ...
# 2017-01-24 20:16:00   "Congratulations to @ FoxNews for being numbe...
# 2017-01-25 06:17:00   "I will be making my Supreme Court pick on Th...
# 2017-01-25 16:05:00   "I will be interviewed by @ DavidMuir tonight...
# 2017-01-25 20:45:00   "' @ romoabcnews: . @ DavidMuir first @ POTUS...
# 2017-01-25 20:48:00   "Interview with David Muir of @ ABC News in 1...
# 2017-01-26 07:51:00   "The U.S. has a 60 billion dollar trade defic...
# 2017-01-26 17:45:00   "Will be interviewed by @ SeanHannity on @ Fo...
# 2017-01-26 17:53:00   "Miami-Dade Mayor drops sanctuary policy. Rig...
# 2017-01-27 10:27:00   "The # MarchForLife is so important. To all o...
# 2017-01-27 10:30:00   ". @ VP Mike Pence will be speaking at today'...
# 2017-01-27 14:20:00   "Statement on International Holocaust Remembr...
# 2017-01-27 16:00:00   "Congratulations Secretary Mattis!pic.twitter...
# 2017-01-27 17:46:00   "I promise that our administration will ALWAY...
# 2017-01-28 07:08:00   "Thr coverage about me in the @ nytimes and t...
# 2017-01-29 07:00:00   "Somebody with aptitude and conviction should...
# 2017-01-29 09:03:00   "Christians in the Middle-East have been exec...
# 2017-01-29 15:45:00   "The joint statement of former presidential c...
# 2017-01-29 17:28:00   "Statement Regarding Recent Executive Order C...
# 2017-01-29 17:39:00   "I will be interviewed by @ TheBrodyFile on @...
# 2017-01-30 06:20:00   "protesters and the tears of Senator Schumer....
# 2017-01-30 06:27:00   "There is nothing nice about searching for te...
# 2017-01-30 07:43:00   "I have made my decision on who I will nomina...
# 2017-01-30 08:23:00   "Where was all the outrage from Democrats and...
# 2017-01-30 18:45:00   "The Democrats are delaying my cabinet picks ...
# 2017-01-31 05:21:00   "Nancy Pelosi and Fake Tears Chuck Schumer he...
# 2017-01-31 05:27:00   "When will the Democrats give us our Attorney...
# 2017-01-31 18:31:00   "Getting ready to deliver a VERY IMPORTANT DE...
# 2017-01-31 19:01:00   "Join me live from the @ WhiteHouse.https://w...
# 2017-02-01 21:06:00   "Iran is rapidly taking over more and more of...
# 2017-02-01 21:55:00   "Do you believe it? The Obama Administration ...
# 2017-02-02 05:13:00   "If U.C. Berkeley does not allow free speech ...
# 2017-02-02 05:18:00   "Congratulations to Rex Tillerson on being sw...
# 2017-02-02 05:25:00   "Attending Chief Ryan Owens' Dignified Transf...
# 2017-02-02 05:34:00   "Iran has been formally PUT ON NOTICE for fir...
# 2017-02-02 05:39:00   "Iran was on its last legs and ready to colla...
# 2017-02-03 05:28:00   "Iran is playing with fire - they don't appre...
# 2017-02-03 05:34:00   "Thank you to Prime Minister of Australia for...
# 2017-02-03 06:51:00   "A new radical Islamic terrorist has just att...
